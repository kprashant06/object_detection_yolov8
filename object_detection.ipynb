# %% [markdown]
# <a href="https://colab.research.google.com/github/kprashant06/object_detection_yolov8/blob/main/object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#copying dataset2 file from drive to the notebook
# !cp -r "/content/drive/MyDrive/dataset2" /content/

# %%
# !ls /content/
# Out:
# dataset2  drive  sample_data

# %%
# !find /content/dataset2/train/labels -type f | head
# Out:
# /content/dataset2/train/labels/7_jpg.rf.cad5633e3e5c4c48dd71d43da6290dfa.txt
# /content/dataset2/train/labels/79_jpg.rf.de4d1285782e25aab9295d0967f117af.txt
# /content/dataset2/train/labels/86_jpg.rf.b85c32a855bfa611d54a4f20e8b01913.txt
# /content/dataset2/train/labels/47_jpg.rf.bc5c13ad955986e6875c275cc8cdb58d.txt
# /content/dataset2/train/labels/55_jpg.rf.6e1b7d6412957a5a68ae80b588a5522e.txt
# /content/dataset2/train/labels/15_jpg.rf.7d3938a22d92485bdfbbabeeae0fc490.txt
# /content/dataset2/train/labels/28_jpg.rf.bbda950c12835f674fdee59465b05505.txt
# /content/dataset2/train/labels/22_jpg.rf.feb473de45f4220101646cb35deda44a.txt
# /content/dataset2/train/labels/13_jpg.rf.8940f48fdfe438128a994c26643e9f89.txt
# /content/dataset2/train/labels/34_jpg.rf.5bf8dca1f990be7d1554d1e93ed72844.txt

# %%
# !ls /content/dataset2/train/images | head
# !ls /content/dataset2/train/labels | head
# Out:
# 11_jpg.rf.98580081a4fd200835652ca9d5b759f9.jpg
# 13_jpg.rf.8940f48fdfe438128a994c26643e9f89.jpg
# 15_jpg.rf.7d3938a22d92485bdfbbabeeae0fc490.jpg
# 18_jpg.rf.9aa4dfbc9472f36e317e82e8fa2527a3.jpg
# 22_jpg.rf.feb473de45f4220101646cb35deda44a.jpg
# 24_jpg.rf.0cc3d7aca6dd02b95424a8e9ac7b4108.jpg
# 25_jpg.rf.a027af9bc2b093f975e560153c509573.jpg
# 27_jpg.rf.a086645a2e7ff6ad3275ad762fc89b48.jpg
# 28_jpg.rf.bbda950c12835f674fdee59465b05505.jpg
# 32_jpg.rf.80bce5c809de99af30dc5e8fcf69776a.jpg
# 11_jpg.rf.98580081a4fd200835652ca9d5b759f9.txt
# 13_jpg.rf.8940f48fdfe438128a994c26643e9f89.txt
# 15_jpg.rf.7d3938a22d92485bdfbbabeeae0fc490.txt
# 18_jpg.rf.9aa4dfbc9472f36e317e82e8fa2527a3.txt
# 22_jpg.rf.feb473de45f4220101646cb35deda44a.txt
# 24_jpg.rf.0cc3d7aca6dd02b95424a8e9ac7b4108.txt
# 25_jpg.rf.a027af9bc2b093f975e560153c509573.txt
# 27_jpg.rf.a086645a2e7ff6ad3275ad762fc89b48.txt
# 28_jpg.rf.bbda950c12835f674fdee59465b05505.txt
# 32_jpg.rf.80bce5c809de99af30dc5e8fcf69776a.txt

# %%
# !find /content/dataset2/train/labels -type f | head
# Out:
# /content/dataset2/train/labels/7_jpg.rf.cad5633e3e5c4c48dd71d43da6290dfa.txt
# /content/dataset2/train/labels/79_jpg.rf.de4d1285782e25aab9295d0967f117af.txt
# /content/dataset2/train/labels/86_jpg.rf.b85c32a855bfa611d54a4f20e8b01913.txt
# /content/dataset2/train/labels/47_jpg.rf.bc5c13ad955986e6875c275cc8cdb58d.txt
# /content/dataset2/train/labels/55_jpg.rf.6e1b7d6412957a5a68ae80b588a5522e.txt
# /content/dataset2/train/labels/15_jpg.rf.7d3938a22d92485bdfbbabeeae0fc490.txt
# /content/dataset2/train/labels/28_jpg.rf.bbda950c12835f674fdee59465b05505.txt
# /content/dataset2/train/labels/22_jpg.rf.feb473de45f4220101646cb35deda44a.txt
# /content/dataset2/train/labels/13_jpg.rf.8940f48fdfe438128a994c26643e9f89.txt
# /content/dataset2/train/labels/34_jpg.rf.5bf8dca1f990be7d1554d1e93ed72844.txt

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data="/content/dataset2/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    name="custom_detector"
)
# Out:
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
#/content/runs/detect/custom_detector-2/weights/best.pt
model = YOLO('/content/runs/detect/custom_detector/weights/best.pt')

results = model.predict(
    source='/content/video1.avi',
    conf=0.25,
    save=True
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/484) /content/video1.avi: 384x640 (no detections), 46.1ms
# video 1/1 (frame 2/484) /content/video1.avi: 384x640 (no detections), 7.0ms
# video 1/1 (frame 3/484) /content/video1.avi: 384x640 (no detections), 8.5ms
# video 1/1 (frame 4/484) /content/video1.avi: 384x640 (no detections), 6.9ms
# video 1/1 (frame 5/484) /content/video1.avi: 384x640 (no detections), 6.2ms
# ...

# %%
from IPython.display import Image

Image(filename='/content/runs/detect/predict/test1.jpg')
